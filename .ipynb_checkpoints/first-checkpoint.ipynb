# %% [markdown]
# ### IMPORT PACKAGES

# %%
import io
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import base64
from skimage.segmentation import slic
from skimage.color import label2rgb, rgb2lab, rgb2hsv
from PIL import Image

# %%
from Linear_Segmentation import apply_slic, stringToImage, ImageTostring

# %% [markdown]
# ### Read Input Image

# %%
img_patch = "./Images/img11.jpg"
img = cv2.imread(img_patch)

test_b64img = ImageTostring(img)

# %% [markdown]
# ### Run the Segmentation - This function is what you need
# - It takes Input Base64 string
# - Outputs Base64 String

# %%
output = apply_slic(test_b64img)

# %% [markdown]
# ### Output for testing purpose

# %%
# Convert the Base64 image back to image 
test_b64 = stringToImage(output)
plt.imshow(test_b64)
plt.show()
